# %%
import pandas as pd
import mysql.connector

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",             # change if your user is different
    password="Hawilax98", # replace with your MySQL password
    database="internship"
)

cursor = conn.cursor()

# Get all table names
cursor.execute("SHOW TABLES")
tables = [table[0] for table in cursor.fetchall()]

# Export each table to a CSV file
for table in tables:
    df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
    df.to_csv(f"{table}.csv", index=False)
    print(f"Exported {table}.csv")

# Cleanup
cursor.close()
conn.close()
# Out:
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# Exported action_events.csv
# Exported assistant_threads.csv
# Exported bot_user.csv
# Exported bots.csv
# Exported categories.csv
# Exported chats.csv
# Exported clients.csv
# Exported companies.csv
# Exported devices.csv
# Exported failed_jobs.csv
# Exported flows.csv
# Exported knowledge.csv
# Exported media.csv
# Exported menu_items.csv
# Exported menus.csv
# Exported migrations.csv
# Exported notifications.csv
# Exported nova_field_attachments.csv
# Exported nova_notifications.csv
# Exported nova_pending_field_attachments.csv
# Exported o_t_p_s.csv
# Exported objects.csv
# Exported order_items.csv
# Exported orders.csv
# Exported password_resets.csv
# Exported personal_access_tokens.csv
# Exported plans.csv
# Exported post_photos.csv
# Exported posts.csv
# Exported refugees.csv
# Exported restaurants.csv
# Exported states.csv
# Exported telescope_entries.csv
# Exported telescope_entries_tags.csv
# Exported telescope_monitoring.csv
# Exported users.csv
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
# C:\Users\player 1\AppData\Local\Temp\ipykernel_16824\2054731610.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM `{table}`", conn)
